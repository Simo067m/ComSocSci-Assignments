# %%
# Import packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from glob import glob
from IPython.display import display

# %%
for f in glob("filtered_data/*"):
    if ".json" not in f: continue
    print(f)
    with pd.option_context('display.max_columns', None):
    # with pd.option_context('display.max_columns', None, 'display.max_colwidth', None):
        display(pd.read_json(f, orient='records', lines=True).head())
# Out:
# filtered_data\final_cast_data_with_movie_list.json
#    gender       id known_for_department    original_name  popularity  \
# 0       0  1568604               Acting      Dee Gruenig       0.840
# 1       2   218563               Acting   Jeffrey Thomas       7.190
# 2       2      108            Directing    Peter Jackson      30.023
# 3       2   109253            Directing      Costa Botes       4.653
# 4       0  4130292               Acting  Beatrice Ashton       0.600
#
#                                             movie_id  \
# 0                           [379576, 786732, 786111]
# 1  [283552, 32458, 354924, 998548, 998581, 429300...
# 2  [254720, 149901, 95758, 166671, 453779, 622231...
# 3                                    [254720, 32458]
# 4                                            [32458]
#
#                                       agg_characters
# 0                                             [, , ]
# 1  [Narrator (voice), Sid, Carl Berry, Thror, Uni...
# ...

# %%
# Load data
movies_df  = pd.read_json(r"filtered_data\final_movie_data.json", orient='records', lines=True)
cast_df    = pd.read_json(r"filtered_data\final_cast_data_with_movie_list.json", orient='records', lines=True)
crew_df    = pd.read_json(r"filtered_data\final_crew_data_with_movie_list.json", orient='records', lines=True)
company_df = pd.read_json(r"filtered_data\production_companies.json", orient='records', lines=True)

# %%
# Return production company details by given company id
get_company = company_df.set_index("id").to_dict(orient="index")
# Production country as dict with Country Code as keys and Country name as values
get_country = pd.read_json(r"filtered_data\production_countries.json", orient='records', lines=True).set_index("Country Code").to_dict(orient="dict")['Country Name']
# Sponken language as dict with Language Code as keys and English name as values:
get_language = pd.read_json(r"filtered_data\spoken_languages.json", orient='records', lines=True).set_index("Language Code").to_dict(orient="dict")['English Name']
# Movie genres
get_genre = pd.read_json(r"filtered_data\movie_genres.json", orient="records", lines=True).set_index("genre_id").to_dict(orient="dict")['genre_name']

# %%
# Check for duplicated id's (in each df, in pairs and all of them together)
has_dub = lambda DF: f"Has duplicates? {str(DF.size!=len(set(DF))).rjust(5)} | {len(set(DF)):>7}/{DF.size:<7} ({DF.size-len(set(DF)):>6} ~ {(DF.size-len(set(DF)))/DF.size*100:.2f}%)"

print(has_dub(movies_df.id))
print(has_dub(cast_df.id))
print(has_dub(crew_df.id))
print(has_dub(company_df.id))
print()
print(has_dub(pd.concat([movies_df.id,cast_df.id])))
print(has_dub(pd.concat([movies_df.id,crew_df.id])))
print(has_dub(pd.concat([cast_df.id,crew_df.id])))
# Out:
# Has duplicates? False |  199897/199897  (     0 ~ 0.00%)
# Has duplicates? False |  531092/531092  (     0 ~ 0.00%)
# Has duplicates? False |  563039/563039  (     0 ~ 0.00%)
# Has duplicates? False |   53299/53299   (     0 ~ 0.00%)
#
# Has duplicates?  True |  713771/730989  ( 17218 ~ 2.36%)
# Has duplicates?  True |  750483/762936  ( 12453 ~ 1.63%)
# Has duplicates?  True | 1018103/1094131 ( 76028 ~ 6.95%)

# %%
# Check which columns can be analysed
print(movies_df.columns)
print(cast_df.columns)
print(crew_df.columns)
print(company_df.columns)
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'imdb_id', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'tagline', 'title', 'vote_average', 'vote_count',
#        'combined_genres', 'cast', 'crew'],
#       dtype='object')
# Index(['gender', 'id', 'known_for_department', 'original_name', 'popularity',
#        'movie_id', 'agg_characters'],
#       dtype='object')
# Index(['gender', 'id', 'known_for_department', 'original_name', 'popularity',
#        'movie_id', 'agg_jobs', 'agg_departments'],
#       dtype='object')
# Index(['id', 'logo_path', 'name', 'origin_country'], dtype='object')

# %%
# Movie:
# budget, original_language, popularity, production_companies, production_countries, 
# release_date, revenue, runtime, spoken_languages, vote_average, 
# vote_count, combined_genres
# Cast:
# gender, known_for_department, popularity, movie_id, agg_characters
# Crew:
# gender, known_for_department, popularity, movie_id, agg_jobs, agg_departments
# Company:
# origin_country

def show_hist(col, title="Histogram", bins=50, logx=False, logy=False):
    cmean,cmedian = np.mean(col), np.median(col)
    fig, ax = plt.subplots(1,1,figsize=(20,8))
    ax.hist(col, bins=bins, color='skyblue', edgecolor='black')
    ax.set_title(title)
    ax.set_xlabel('Values')
    ax.set_ylabel('Count')
    ax.set_xscale('log' if logx else 'linear')
    ax.set_yscale('log' if logy else 'linear')
    if cmean > 10000: ax.axvline(cmean, color="blue", label=f"Mean: {np.mean(col):.3e}")
    else:             ax.axvline(cmean, color="blue", label=f"Mean: {np.mean(col):.3f}")
    if cmedian > 10000: ax.axvline(cmedian, color="green", label=f"Median: {np.median(col):.3e}")
    else:               ax.axvline(cmedian, color="green", label=f"Median: {np.median(col):.3f}")
    ax.legend()
    plt.show()
    
def show_list_count(col, apply_mapping = None, measure_str = "", top_count=15, bottom_count=15, use_barplot=True, logy=False):
    exploded_col = col.explode()
    if apply_mapping:
        exploded_col = exploded_col.map(apply_mapping)
    count_col = exploded_col.value_counts()
    if use_barplot:
        fig, ax = plt.subplots(1,1,figsize=(20,12))
        ax.barh(list(count_col.head(top_count).index), list(count_col.head(top_count).values), color='skyblue', edgecolor='black')
        # ax.set_xlabel('')
        ax.set_title(f"Top {top_count if top_count < count_col.size else ''}{measure_str}:")
        ax.set_xlabel('Count')
        ax.set_xscale('log' if logy else 'linear')
        plt.show()
    else:
        print(f"Top {top_count}{measure_str}:")
        display(count_col.head(top_count))
        print(f"\nBottom {bottom_count}{measure_str}:")
        display(count_col.tail(bottom_count))

# %%
# Movie: budget
show_hist(movies_df["budget"], title="Budget histogram", logy=True, logx=True)

# %%
# Movie: original_language
movies_df["original_language"].value_counts()
# Out:
# en    199894
# ja         1
# hi         1
# fr         1
# Name: original_language, dtype: int64

# %%
# Movie: popularity
show_hist(movies_df["popularity"], title="Popularity hist", bins=100, logy=True)

# %%
# production_companies
mapping_func = lambda id: get_company[id]["name"] if id in get_company else None
show_list_count(movies_df["production_companies"], apply_mapping=mapping_func, measure_str=" company publishes count", top_count=50, use_barplot=True, logy=True)

# %%
# production_countries
show_list_count(movies_df["production_countries"], measure_str=" country publishes count", top_count=50, use_barplot=True, logy=True)

# %%
# Movie : release_date
# show_list_count(movies_df["release_date"].map(lambda dd: dd.split("-")[0]), measure_str="most published years", top_count=50, use_barplot=True, logy=False)
movies_df["release_date"].map(lambda dd: dd.split("-")[0]).value_counts()
# Out:
# 2017    10000
# 2013    10000
# 2018     9999
# 2020     9998
# 2015     9998
# 2014     9998
# 2016     9997
# 2022     9996
# 2019     9995
# 2021     9993
# 2023     9991
# 2012     9740
# 2011     8926
# 2010     8070
# 2009     7960
# 2008     7580
# 2007     7130
# 2006     7071
# 2005     6314
# 2004     5633
# 2003     5090
# 2002     4565
# 2001     4080
# 2024     4017
# 2000     3756
# Name: release_date, dtype: int64

# %%
# Movie: revenue
show_hist(movies_df["revenue"],title="Movie revenue",logy=True)

# %%
# Movie: runtime
show_hist(movies_df["runtime"], bins=30, title="Movie runtime in seconds", logy=True)

# %%
# Movie: spoken_languages
show_list_count(movies_df["spoken_languages"], measure_str=" country publishes count", top_count=50, use_barplot=True, logy=True)

# %%
# Movie: vote_average
show_hist(movies_df["vote_average"],title="Vote Average",logy=True)

# %%
# Movie: vote_count
show_hist(movies_df["vote_count"],title="Vote Count",logy=True)

# %%
# Movie: combined_genres
mapping_func = lambda id: get_genre[id] if id in get_company else None
show_list_count(movies_df["combined_genres"], apply_mapping=mapping_func, measure_str="genres", top_count=50, use_barplot=True, logy=True)

# %%
# Cast: gender
cast_df["gender"].value_counts()
# Out:
# 0    361619
# 2    101792
# 1     67278
# 3       403
# Name: gender, dtype: int64

# %%
# Cast: known_for_department
show_list_count(cast_df["known_for_department"], measure_str="known for", logy=True)

# %%
# Cast: popularity
show_hist(cast_df["popularity"], title="Cast popularity chart", logy=True)

# %%
# Cast: movie_id, number of movies worked on
show_hist(cast_df["movie_id"].map(len),title="Number of movies worked on", logy=True)

# %%
# Cast: agg_characters
show_list_count(cast_df["agg_characters"],measure_str=" played as cast",top_count=25,use_barplot=True,logy=True)

# %%
# Crew: gender
crew_df["gender"].value_counts()
# Out:
# 0    454199
# 2     76060
# 1     32433
# 3       347
# Name: gender, dtype: int64

# %%
# Crew: known_for_department
show_list_count(crew_df["known_for_department"], measure_str="crew known for", logy=True)

# %%
# Crew: popularity
show_hist(crew_df["popularity"], title="Crew popularity chart", logy=True)

# %%
# Crew: movie_id, number of movies worked on
show_hist(crew_df["movie_id"].map(len),title="Number of movies worked on", logy=True)

# %%
# Crew: agg_jobs
show_list_count(crew_df["agg_jobs"],measure_str=" most common crew jobs",top_count=25,use_barplot=True,logy=True)

# %%
# Crew: agg_departments
show_list_count(crew_df["agg_departments"],measure_str="crew department",top_count=25,use_barplot=True,logy=True)

# %%
show_list_count(company_df["origin_country"], measure_str=" most country publish count", top_count=25, logy=True)
